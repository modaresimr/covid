# %%
### %matplotlib inline
import pandas as pd
from IPython.display import Image

import importlib
import ali.methods
import ali.ui
import ali.eval
import ali.multi_run

importlib.reload(ali.methods)
importlib.reload(ali.ui)
importlib.reload(ali.eval)
importlib.reload(ali.multi_run)

args = {
#     'methods' : [
#         'if',#'isolationforest',
#         'nightsignal',
#         'ns_orig',
#         'alisignal_60',
#         'random',
#         'CuSum',
#         'use-all'   
#     ],
#     'methods' : [f'alisignal_{seg:3.0f}' for seg in range(30,7*60,30)],
    'methods' : ['if2'],
    'parallel':0,
    'debug': 1,
    'show_exception':1,
    'only_positive':1,
#     'only_device':'AppleWatch'

}


ali.multi_run.run(args)
"finished"
# Out:
# runing... args={'methods': ['if2'], 'parallel': 0, 'debug': 1, 'show_exception': 1, 'only_positive': 1}
# id=P110465 Incompatible indexer with Series
# Traceback (most recent call last):
#   File "/workspace/COVID/ali/multi_run.py", line 115, in parrun
#     return (id, {'eval': methods.run(run_methods=run_methods, id=id, args=args)},data)
#   File "/workspace/COVID/ali/methods.py", line 485, in run
#     df.loc[method,item] = ev[item]
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 723, in __setitem__
#     iloc._setitem_with_indexer(indexer, value, self.name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1689, in _setitem_with_indexer
#     self._setitem_with_indexer(new_indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1732, in _setitem_with_indexer
#     self._setitem_single_block(indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1959, in _setitem_single_block
#     value = self._align_series(indexer, Series(value))
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 2149, in _align_series
#     raise ValueError("Incompatible indexer with Series")
# ValueError: Incompatible indexer with Series
# id=P111019 Incompatible indexer with Series
# Traceback (most recent call last):
#   File "/workspace/COVID/ali/multi_run.py", line 115, in parrun
#     return (id, {'eval': methods.run(run_methods=run_methods, id=id, args=args)},data)
#   File "/workspace/COVID/ali/methods.py", line 485, in run
#     df.loc[method,item] = ev[item]
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 723, in __setitem__
#     iloc._setitem_with_indexer(indexer, value, self.name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1689, in _setitem_with_indexer
#     self._setitem_with_indexer(new_indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1732, in _setitem_with_indexer
#     self._setitem_single_block(indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1959, in _setitem_single_block
#     value = self._align_series(indexer, Series(value))
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 2149, in _align_series
#     raise ValueError("Incompatible indexer with Series")
# ValueError: Incompatible indexer with Series
# id=P148618 Incompatible indexer with Series
# Traceback (most recent call last):
#   File "/workspace/COVID/ali/multi_run.py", line 115, in parrun
#     return (id, {'eval': methods.run(run_methods=run_methods, id=id, args=args)},data)
#   File "/workspace/COVID/ali/methods.py", line 485, in run
#     df.loc[method,item] = ev[item]
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 723, in __setitem__
#     iloc._setitem_with_indexer(indexer, value, self.name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1689, in _setitem_with_indexer
#     self._setitem_with_indexer(new_indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1732, in _setitem_with_indexer
#     self._setitem_single_block(indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1959, in _setitem_single_block
#     value = self._align_series(indexer, Series(value))
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 2149, in _align_series
#     raise ValueError("Incompatible indexer with Series")
# ValueError: Incompatible indexer with Series
# id=P167406 Incompatible indexer with Series
# Traceback (most recent call last):
#   File "/workspace/COVID/ali/multi_run.py", line 115, in parrun
#     return (id, {'eval': methods.run(run_methods=run_methods, id=id, args=args)},data)
#   File "/workspace/COVID/ali/methods.py", line 485, in run
#     df.loc[method,item] = ev[item]
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 723, in __setitem__
#     iloc._setitem_with_indexer(indexer, value, self.name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1689, in _setitem_with_indexer
#     self._setitem_with_indexer(new_indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1732, in _setitem_with_indexer
#     self._setitem_single_block(indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1959, in _setitem_single_block
#     value = self._align_series(indexer, Series(value))
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 2149, in _align_series
#     raise ValueError("Incompatible indexer with Series")
# ValueError: Incompatible indexer with Series
# id=P182427 Incompatible indexer with Series
# Traceback (most recent call last):
#   File "/workspace/COVID/ali/multi_run.py", line 115, in parrun
#     return (id, {'eval': methods.run(run_methods=run_methods, id=id, args=args)},data)
#   File "/workspace/COVID/ali/methods.py", line 485, in run
#     df.loc[method,item] = ev[item]
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 723, in __setitem__
#     iloc._setitem_with_indexer(indexer, value, self.name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1689, in _setitem_with_indexer
#     self._setitem_with_indexer(new_indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1732, in _setitem_with_indexer
#     self._setitem_single_block(indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1959, in _setitem_single_block
#     value = self._align_series(indexer, Series(value))
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 2149, in _align_series
#     raise ValueError("Incompatible indexer with Series")
# ValueError: Incompatible indexer with Series
# id=P196430 Incompatible indexer with Series
# Traceback (most recent call last):
#   File "/workspace/COVID/ali/multi_run.py", line 115, in parrun
#     return (id, {'eval': methods.run(run_methods=run_methods, id=id, args=args)},data)
#   File "/workspace/COVID/ali/methods.py", line 485, in run
#     df.loc[method,item] = ev[item]
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 723, in __setitem__
#     iloc._setitem_with_indexer(indexer, value, self.name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1689, in _setitem_with_indexer
#     self._setitem_with_indexer(new_indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1732, in _setitem_with_indexer
#     self._setitem_single_block(indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1959, in _setitem_single_block
#     value = self._align_series(indexer, Series(value))
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 2149, in _align_series
#     raise ValueError("Incompatible indexer with Series")
# ValueError: Incompatible indexer with Series
# id=P203215 Incompatible indexer with Series
# Traceback (most recent call last):
#   File "/workspace/COVID/ali/multi_run.py", line 115, in parrun
#     return (id, {'eval': methods.run(run_methods=run_methods, id=id, args=args)},data)
#   File "/workspace/COVID/ali/methods.py", line 485, in run
#     df.loc[method,item] = ev[item]
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 723, in __setitem__
#     iloc._setitem_with_indexer(indexer, value, self.name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1689, in _setitem_with_indexer
#     self._setitem_with_indexer(new_indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1732, in _setitem_with_indexer
#     self._setitem_single_block(indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1959, in _setitem_single_block
#     value = self._align_series(indexer, Series(value))
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 2149, in _align_series
#     raise ValueError("Incompatible indexer with Series")
# ValueError: Incompatible indexer with Series
# id=P206998 Incompatible indexer with Series
# Traceback (most recent call last):
#   File "/workspace/COVID/ali/multi_run.py", line 115, in parrun
#     return (id, {'eval': methods.run(run_methods=run_methods, id=id, args=args)},data)
#   File "/workspace/COVID/ali/methods.py", line 485, in run
#     df.loc[method,item] = ev[item]
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 723, in __setitem__
#     iloc._setitem_with_indexer(indexer, value, self.name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1689, in _setitem_with_indexer
#     self._setitem_with_indexer(new_indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1732, in _setitem_with_indexer
#     self._setitem_single_block(indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1959, in _setitem_single_block
#     value = self._align_series(indexer, Series(value))
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 2149, in _align_series
#     raise ValueError("Incompatible indexer with Series")
# ValueError: Incompatible indexer with Series
# id=P209134 Incompatible indexer with Series
# Traceback (most recent call last):
#   File "/workspace/COVID/ali/multi_run.py", line 115, in parrun
#     return (id, {'eval': methods.run(run_methods=run_methods, id=id, args=args)},data)
#   File "/workspace/COVID/ali/methods.py", line 485, in run
#     df.loc[method,item] = ev[item]
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 723, in __setitem__
#     iloc._setitem_with_indexer(indexer, value, self.name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1689, in _setitem_with_indexer
#     self._setitem_with_indexer(new_indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1732, in _setitem_with_indexer
#     self._setitem_single_block(indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1959, in _setitem_single_block
#     value = self._align_series(indexer, Series(value))
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 2149, in _align_series
#     raise ValueError("Incompatible indexer with Series")
# ValueError: Incompatible indexer with Series
# id=P214671 Incompatible indexer with Series
# Traceback (most recent call last):
#   File "/workspace/COVID/ali/multi_run.py", line 115, in parrun
#     return (id, {'eval': methods.run(run_methods=run_methods, id=id, args=args)},data)
#   File "/workspace/COVID/ali/methods.py", line 485, in run
#     df.loc[method,item] = ev[item]
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 723, in __setitem__
#     iloc._setitem_with_indexer(indexer, value, self.name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1689, in _setitem_with_indexer
#     self._setitem_with_indexer(new_indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1732, in _setitem_with_indexer
#     self._setitem_single_block(indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1959, in _setitem_single_block
#     value = self._align_series(indexer, Series(value))
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 2149, in _align_series
#     raise ValueError("Incompatible indexer with Series")
# ValueError: Incompatible indexer with Series
# id=P219295 Incompatible indexer with Series
# Traceback (most recent call last):
#   File "/workspace/COVID/ali/multi_run.py", line 115, in parrun
#     return (id, {'eval': methods.run(run_methods=run_methods, id=id, args=args)},data)
#   File "/workspace/COVID/ali/methods.py", line 485, in run
#     df.loc[method,item] = ev[item]
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 723, in __setitem__
#     iloc._setitem_with_indexer(indexer, value, self.name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1689, in _setitem_with_indexer
#     self._setitem_with_indexer(new_indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1732, in _setitem_with_indexer
#     self._setitem_single_block(indexer, value, name)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 1959, in _setitem_single_block
#     value = self._align_series(indexer, Series(value))
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py", line 2149, in _align_series
#     raise ValueError("Incompatible indexer with Series")
# ValueError: Incompatible indexer with Series
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     499     try:
# --> 500         fh = fp.fileno()
#     501         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-6ae6b2c9b267> in <module>
#      35
#      36
# ---> 37 ali.multi_run.run(args)
#      38 "finished"
#
# /workspace/COVID/ali/multi_run.py in run(args)
#      67     else:
#      68
# ---> 69         result = [runner(data) for data in ids.values()]
#      70         for i, (id, out, data) in enumerate(result):
#      71             if 'eval' in out:
#
# /workspace/COVID/ali/multi_run.py in <listcomp>(.0)
#      67     else:
#      68
# ---> 69         result = [runner(data) for data in ids.values()]
#      70         for i, (id, out, data) in enumerate(result):
#      71             if 'eval' in out:
#
# /workspace/COVID/ali/multi_run.py in parrun(data, args)
#     113                     # myzip.extract(data['hr'],'/tmp/covidtmp/{id}/hr.csv')
#     114                 methods.convert(hr_file=hrf, step_file=stepf, info=data,force=False)
# --> 115                 return (id, {'eval': methods.run(run_methods=run_methods, id=id, args=args)},data)
#     116
#     117     #             print(f'res={res} total={total_res}')
#
# /workspace/COVID/ali/methods.py in run(run_methods, id, args)
#     477     allAlarms.to_csv(f'output/my/{id}/alarm.csv')
#     478
# --> 479     ui.plotAll(rhr=rhr, alerts=allAlarms.drop(['random'],axis=1), info=info,
#     480            file=f'output/my/{id}/all.png', show=args.get('debug',0))
#     481     for method in run_methods:
#
# /workspace/COVID/ali/ui.py in plotAll(rhr, alerts, info, file, show)
#     210
#     211     if file:
# --> 212         plt.gcf().savefig(file, dpi=300, bbox_inches="tight")
#     213     if show:
#     214         plt.show()
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3010                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3011
# -> 3012             self.canvas.print_figure(fname, **kwargs)
#    3013
#    3014     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2312                 # force the figure dpi to 72), so we need to set it again here.
#    2313                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2314                     result = print_method(
#    2315                         filename,
#    2316                         facecolor=facecolor,
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1641             kwargs.pop(arg)
#    1642
# -> 1643         return func(*args, **kwargs)
#    1644
#    1645     return wrapper
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                          else deprecation_addendum,
#     411                 **kwargs)
# --> 412         return func(*inner_args, **inner_kwargs)
#     413
#     414     DECORATORS[wrapper] = decorator
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     539         """
#     540         FigureCanvasAgg.draw(self)
# --> 541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1673         pil_kwargs.setdefault("format", format)
#    1674         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1675         image.save(fname, **pil_kwargs)
#    1676
#    1677
#
# /opt/conda/lib/python3.8/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2170
#    2171         try:
# -> 2172             save_handler(self, fp, filename)
#    2173         finally:
#    2174             # do what we can to clean up
#
# /opt/conda/lib/python3.8/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1333         _write_multiple_frames(im, fp, chunk, rawmode)
#    1334     else:
# -> 1335         ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1336
#    1337     if info:
#
# /opt/conda/lib/python3.8/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     512             else:
#     513                 while True:
# --> 514                     l, s, d = e.encode(bufsize)
#     515                     fp.write(d)
#     516                     if s:
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f06cd3d15e0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/matplotlib/pyplot.py in post_execute()
#     136     def post_execute():
#     137         if matplotlib.is_interactive():
# --> 138             draw_all()
#     139
#     140     try:  # IPython >= 2
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     135         for manager in cls.get_all_fig_managers():
#     136             if force or manager.canvas.figure.stale:
# --> 137                 manager.canvas.draw_idle()
#     138
#     139
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
#    2054             with self._idle_draw_cntx():
# -> 2055                 self.draw(*args, **kwargs)
#    2056
#    2057     @property
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2801
#    2802             self.patch.draw(renderer)
# -> 2803             mimage._draw_list_compositing_images(
#    2804                 renderer, self, artists, self.suppressComposite)
#    2805
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3080             renderer.stop_rasterizing()
#    3081
# -> 3082         mimage._draw_list_compositing_images(
#    3083             renderer, self, artists, self.figure.suppressComposite)
#    3084
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1161
#    1162         for tick in ticks_to_draw:
# -> 1163             tick.draw(renderer)
#    1164
#    1165         # scale up the axis label box to also find the neighbors, not
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/axis.py in draw(self, renderer)
#     297         for artist in [self.gridline, self.tick1line, self.tick2line,
#     298                        self.label1, self.label2]:
# --> 299             artist.draw(renderer)
#     300         renderer.close_group(self.__name__)
#     301         self.stale = False
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/text.py in draw(self, renderer)
#     683
#     684         with self._cm_set(text=self._get_wrapped_text()):
# --> 685             bbox, info, descent = self._get_layout(renderer)
#     686             trans = self.get_transform()
#     687
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     315             clean_line, ismath = self._preprocess_math(line)
#     316             if clean_line:
# --> 317                 w, h, d = renderer.get_text_width_height_descent(
#     318                     clean_line, self._fontproperties, ismath=ismath)
#     319             else:
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     268         flags = get_hinting_flag()
#     269         font = self._get_agg_font(prop)
# --> 270         font.set_text(s, 0.0, flags=flags)
#     271         w, h = font.get_width_height()  # width and height of unrotated string
#     272         d = font.get_descent()
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7f06cddb80d0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# /opt/conda/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# /opt/conda/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     248
#     249     if 'png' in formats:
# --> 250         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     251     if 'retina' in formats or 'png2x' in formats:
#     252         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     132         FigureCanvasBase(fig)
#     133
# --> 134     fig.canvas.print_figure(bytes_io, **kw)
#     135     data = bytes_io.getvalue()
#     136     if fmt == 'svg':
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2288                 )
#    2289                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2290                     self.figure.draw(renderer)
#    2291
#    2292             if bbox_inches:
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2801
#    2802             self.patch.draw(renderer)
# -> 2803             mimage._draw_list_compositing_images(
#    2804                 renderer, self, artists, self.suppressComposite)
#    2805
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3080             renderer.stop_rasterizing()
#    3081
# -> 3082         mimage._draw_list_compositing_images(
#    3083             renderer, self, artists, self.figure.suppressComposite)
#    3084
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1161
#    1162         for tick in ticks_to_draw:
# -> 1163             tick.draw(renderer)
#    1164
#    1165         # scale up the axis label box to also find the neighbors, not
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/axis.py in draw(self, renderer)
#     297         for artist in [self.gridline, self.tick1line, self.tick2line,
#     298                        self.label1, self.label2]:
# --> 299             artist.draw(renderer)
#     300         renderer.close_group(self.__name__)
#     301         self.stale = False
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/text.py in draw(self, renderer)
#     731                                           mtext=mtext)
#     732                 else:
# --> 733                     textrenderer.draw_text(gc, x, y, clean_line,
#     734                                            self._fontproperties, angle,
#     735                                            ismath=ismath, mtext=mtext)
#
# /opt/conda/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in _cm_set(self, **kwargs)
#    1174             yield
#    1175         finally:
# -> 1176             self.set(**orig_vals)
#    1177
#    1178     def findobj(self, match=None, include_self=True):
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in <lambda>(self, **kwargs)
#     114             return
#     115
# --> 116         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     117         cls.set.__name__ = "set"
#     118         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1162         # module.
#    1163         kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1164         return self.update(kwargs)
#    1165
#    1166     @contextlib.contextmanager
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/text.py in update(self, kwargs)
#     162     def update(self, kwargs):
#     163         # docstring inherited
# --> 164         kwargs = cbook.normalize_kwargs(kwargs, Text)
#     165         sentinel = object()  # bbox can be None, so use another sentinel.
#     166         # Update fontproperties first, as it has lowest priority.
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in normalize_kwargs(kw, alias_mapping)
#    1736     for k, v in kw.items():
#    1737         canonical = to_canonical.get(k, k)
# -> 1738         if canonical in canonical_to_seen:
#    1739             raise TypeError(f"Got both {canonical_to_seen[canonical]!r} and "
#    1740                             f"{k!r}, which are aliases of one another")
#
# KeyboardInterrupt:

# %%
import ali.methods
hr,step,rhr,info=ali.methods.load('P678649')

# %%
rhr#.resample('1D').mean().dropna().round(0).astype(int)
import pandas as pd
# rhr.loc[(rhr.index.day==27) & (rhr.index.month==1)].astype(int).resample('1D').mean()
pd.Timedelta(days=(info['covid_test_date']-rhr.index[0]).days//7*7)

# %%
import ali.new_method
import importlib
importlib.reload(ali.new_method)
importlib.reload(ali.eval)

ali.new_method.reEvalAll()

# %%
import os 
import pandas as pd
from IPython.display import Image
for id in os.listdir('output/my'):
    print(id)
#     display(pd.read_csv(f'output/my/{id}/eval.csv'))
#     for img in sorted(os.listdir(f'output/my/{id}/')):
#         if '.png' in img and 'random' not in img and 'alisignal' not in img:
#             display(Image(f'output/my/{id}/{img}'))
    display(Image(f'output/my/{id}/all.png'))
